# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
# reading the data
df = pd.read_csv('ev_cleaned_data.csv')
df.head()
# Out:
#                                                 name   price  rating  \
# 0  Bounce Infinity E1 Limited Edition Booking for...  114208     4.0
# 1  Joy e-bike Wolf Eco Booking for Ex-Showroom Pr...   91350     4.4
# 2  OKAYA Faast F2B Booking for Ex-Showroom Price ...   99950     4.3
# 3  BGauss BG C12i MAX Booking for Ex-Showroom Pri...  126153     4.2
# 4  VIDA Powered by Hero V1 Pro Booking for Ex-Sho...  145900     4.2
#
#            company  rating_count  review_count
# 0  Bounce Infinity            40            12
# 1              Joy            28             7
# 2            OKAYA           594            92
# 3           BGauss            49             5
# 4             VIDA           217            39

# %%
df.tail()
# Out:
#                                                  name   price  rating  \
# 71  OKAYA ClassIQ Booking for Ex-Showroom Price (w...   74499     4.0
# 72  BGauss BG D15 Pro Booking for Ex-Showroom Pric...  145651     3.5
# 73  BGauss BG B8 Booking for Ex-Showroom Price (Wi...   50000     3.6
# 74  OKAYA Faast F3 Booking for Ex-Showroom Price (...  124990     3.7
# 75  Bounce Infinity E1 Booking for Ex-Showroom Pri...   80490     4.0
#
#             company  rating_count  review_count
# 71            OKAYA             4             0
# 72           BGauss             6             4
# 73           BGauss            22             5
# 74            OKAYA             3             0
# 75  Bounce Infinity            96            31

# %%
# checking the dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          76 non-null     object
#  1   price         76 non-null     int64
#  2   rating        76 non-null     float64
#  3   company       76 non-null     object
#  4   rating_count  76 non-null     int64
#  5   review_count  76 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 3.7+ KB

# %% [markdown]
# Here we have <b>six</b> columns, <b>two</b> contain categorical data and <b>four</b> contain numeric data
# - Numerical Columns: `Price`, `Rating`, `Rating Count`, `Review Count` </li>
# - Categorical Columns: `Company`, `Name` </li>

# %%
df.describe()
# Out:
#                price     rating  rating_count  review_count
# count      76.000000  76.000000     76.000000     76.000000
# mean   112841.078947   3.969737     74.039474     12.513158
# std     24026.096180   0.260778    130.258967     19.908118
# min     50000.000000   3.500000      3.000000      0.000000
# 25%     99950.000000   3.800000      6.000000      1.000000
# 50%    109604.000000   4.000000     22.000000      5.000000
# 75%    132990.000000   4.200000     49.000000     12.000000
# max    146355.000000   4.400000    594.000000     92.000000

# %%
df.plot('price', kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
fig, axs = plt.subplots(2,2)

axs[0,0].hist(df['price'], bins=10, color = 'blue', alpha = 0.7)
axs[0,0].set_title("Histogram of Price")
axs[0,1].hist(df['rating'],bins=10, color = 'darkred', alpha = 0.7)
axs[0,1].set_title("Histogram of Rating")
axs[1,0].hist(df['rating_count'], bins=10, color = 'green', alpha = 0.7)
axs[1,0].set_title("Histogram of Rating Count")
axs[1,1].hist(df['review_count'], bins=10, color = 'yellow' , alpha = 0.7)
axs[1,1].set_title("Histogram of Review Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Inference</b>
# - price: Data has more records towards the *min* and *max* and relatively lesser number of records around the middle of the data
# - rating: Most of the records have the rating of `4.0` and `4.4` is the second in terms of record frequency. <br> There are no records in the rating range of `4.5` to `4.9`
# - review_count: Here the review counts are spread around from `0-80` but a large amount of records fall under the `0` review range

# %%
df.company.value_counts()
# Out:
# company
# Okaya              24
# Bgauss             19
# Vida                8
# Ampere              5
# Joy                 3
# Bounce Infinity     1
# Name: count, dtype: int64

# %%
df.company.value_counts().plot( kind= 'barh');
plt.title("Number of Electric Scooter Listed on Flipkart by Each Company")
plt.xlabel('Number of Electric Scooters Listed')
plt.ylabel('Name of Company')
plt.show()

# %% [markdown]
# In terms of company:
# - Okaya has the most Electric Scooters listed on Flipkart
# - BGauss at second place
# - Bounce Infinity being the least in terms of number i.e 1

# %%
plt.scatter(df.rating,df.price)
plt.title("Scatter plot of Price and Rating")
plt.xlabel("Rating")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# <b>Inference:</b>
# - Here we can see that Price and Rating have positive correlation as Increase in Price also displayed increase in Rating
# - There are a few exceptions to this case where a few 5 star review come from a lower price range and that can be something that we can look into in the future

# %%
plt.scatter(df.price,df.rating_count)

# %%
<b>Inference:</b>
- There isnt't a strong correlatio

# %%
plt.scatter(df.price, df.review_count)
