# %%
# installing ydata-profiling
# !pip install ydata-profiling
# Out:
# ...
#                                               0.0/357.6 kB ? eta -:--:--
#      --------------------                   194.6/357.6 kB 5.9 MB/s eta 0:00:01
#      -------------------------------------- 357.6/357.6 kB 4.5 MB/s eta 0:00:00
# ...
#                                               0.0/381.9 kB ? eta -:--:--
#      -----------------------------          297.0/381.9 kB 6.1 MB/s eta 0:00:01
#      -------------------------------------- 381.9/381.9 kB 4.8 MB/s eta 0:00:00
# ...
#                                               0.0/102.7 kB ? eta -:--:--
#      -------------------------------------- 102.7/102.7 kB 3.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#                                               0.0/663.4 kB ? eta -:--:--
#      ---------                              163.8/663.4 kB 9.6 MB/s eta 0:00:01
#      ---------------                        276.5/663.4 kB 3.4 MB/s eta 0:00:01
# ...

# %%
# loading ydata_profiling package
from ydata_profiling import ProfileReport

# %%
import pandas as pd

# %%
df = pd.read_csv('ev_cleaned_data.csv')

# %%
# using ProfileReport
pr_df = ProfileReport(df)

# %%
pr_df
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-01-01 09:09:54.171429&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# installing sweeetviz
# !pip install sweetviz
# Out:
# ...
#                                               0.0/15.1 MB ? eta -:--:--
#                                               0.3/15.1 MB 5.9 MB/s eta 0:00:03
#      -                                        0.6/15.1 MB 7.1 MB/s eta 0:00:03
#      --                                       0.9/15.1 MB 7.0 MB/s eta 0:00:03
#      --                                       1.1/15.1 MB 6.4 MB/s eta 0:00:03
#      ---                                      1.4/15.1 MB 6.2 MB/s eta 0:00:03
#      ----                                     1.6/15.1 MB 6.0 MB/s eta 0:00:03
#      ----                                     1.8/15.1 MB 5.9 MB/s eta 0:00:03
#      -----                                    2.0/15.1 MB 5.5 MB/s eta 0:00:03
#      -----                                    2.1/15.1 MB 5.2 MB/s eta 0:00:03
#      ------                                   2.3/15.1 MB 5.0 MB/s eta 0:00:03
#      ------                                   2.4/15.1 MB 4.8 MB/s eta 0:00:03
# ...

# %%
# loading sweetviz 
import sweetviz

# %%
analyse = sweetviz.analyze([df,'df'])
analyse.show_html('analyze.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report analyze.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
